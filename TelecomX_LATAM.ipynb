# %% [markdown]
# <a href="https://colab.research.google.com/github/julioguzmanc/Challenge-Telecom-X/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
telecomX_data = pd.read_json('https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json')

# %%
telecomX_data.info(
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
telecomX_data.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %%
# Normalizando las columnas 'customer', 'phone', 'internet', y 'account'
customer_data = pd.json_normalize(telecomX_data['customer'])
phone_data = pd.json_normalize(telecomX_data['phone'])
internet_data = pd.json_normalize(telecomX_data['internet'])
account_data = pd.json_normalize(telecomX_data['account'])

# Concatenando los dataframes normalizados con el dataframe original
telecomX_normalized = pd.concat([telecomX_data[['customerID', 'Churn']],
                                 customer_data,
                                 phone_data,
                                 internet_data,
                                 account_data], axis=1)

# %%
display(telecomX_normalized.head())
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
telecomX_normalized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
telecomX_normalized.to_csv('telecomX_normalized.csv', index=False)

# %%
list(telecomX_normalized.columns)
# Out:
# ['customerID',
#  'Churn',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Charges.Monthly',
#  'Charges.Total']

# %%
# Convertir columnas 'Yes'/'No' a boolean
yes_no_cols = ['Churn', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'OnlineSecurity',
               'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
               'StreamingMovies', 'PaperlessBilling']

for col in yes_no_cols:
    telecomX_normalized[col] = telecomX_normalized[col].map({'Yes': True, 'No': False}).astype(bool)

# Manejar 'No phone service' y 'No internet service' en MultipleLines y otras columnas relacionadas con internet
# Re-aplicando el mapeo y luego astype(bool) para asegurar el manejo correcto de "No phone service" y "No internet service"
telecomX_normalized['MultipleLines'] = telecomX_normalized['MultipleLines'].map({'Yes': True, 'No': False, 'No phone service': False}).astype(bool)
for col in ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
               'StreamingTV', 'StreamingMovies']:
     telecomX_normalized[col] = telecomX_normalized[col].map({'Yes': True, 'No': False, 'No internet service': False}).astype(bool)

# Convertir 'Charges.Total' a numérico, forzando errores
telecomX_normalized['Charges.Total'] = pd.to_numeric(telecomX_normalized['Charges.Total'], errors='coerce')

# %%
# Mostrar los tipos de datos después de la conversión
telecomX_normalized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   bool
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   bool
#  5   Dependents        7267 non-null   bool
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   bool
#  8   MultipleLines     7267 non-null   bool
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   bool
#  11  OnlineBackup      7267 non-null   bool
#  12  DeviceProtection  7267 non-null   bool
#  13  TechSupport       7267 non-null   bool
#  14  StreamingTV       7267 non-null   bool
#  15  StreamingMovies   7267 non-null   bool
#  16  Contract          7267 non-null   object
# ...

# %% [markdown]
# #📄Informe final

# %% [markdown]
# Según el diccionario de datos y pensando en el problema de que los clientes se den de baja, estas son las columnas que más servirían para el análisis. Se puede observar que las columnas customer, phone, internet y account son de tipo object y contienen diccionarios o datos anidados en formato de cadena de texto:
#
# **CustomerID**: Fundamental para identificar a cada cliente de forma única.
#
# **Churn**: Variable objetivo del análisis, la que se busca predecir.
#
# **SeniorCitizen**: la edad influye en qué tan cómodo se siente con la tecnología y qué servicios necesita.
#
# **Partner**: Si el cliente tiene pareja, podría indicar un tipo de hogar o necesidades distintas.
#
# **Dependents**: Tener dependientes podría influir en las decisiones sobre los servicios.
#
# **tenure**: cuánto tiempo lleva el cliente con la empresa. Si ha estado mucho tiempo, probablemente sea más fiel.
#
# **PhoneService y InternetService**: Estos indican los servicios principales contratados.
#
# **MultipleLines, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies**: Estos son servicios adicionales. La cantidad y el tipo de servicios extra que un cliente contrata puede ser un indicador de su compromiso.
#
# **Contract**: el tipo de contrato que tiene. Los contratos largos suelen hacer que la gente se quede más.
#
# **PaperlessBilling**: La preferencia por la facturación digital puede estar ligada a un perfil de cliente específico.
#
# **PaymentMethod**: El método de pago puede ofrecer información sobre la estabilidad del cliente.
#
# **Charges.Monthly**: lo que paga cada mes. Si es muy alto o cambia mucho, puede empujar a un cliente a irse.
#
# **Charges.Total**: el total que ha pagado hasta ahora. Al igual que el mensual, dice cuánto ha invertido en el servicio.
#
# Estas columnas, junto con la variable Churn, son clave para armar modelos que predigan quién podría irse y entender por qué.
